# %%
# import dependencies
import pandas as pd
import random
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities= []

# identify the nearest city for each lat and  long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then add to cities list
    if city not in cities:
        cities.append(city)

# %%
# starting url for Weather Map api call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an empty list to hold the weather data
city_data = []

# print beginning of the log
print("Beginning Data Retrieval     ")
print("-----------------------------")

# set counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# loop through all the cities in list
for i, city in enumerate(cities):

    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # log url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # add 1 to record count
    record_count += 1
    
# run the API request for each of the cities
    try:
        # parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # select only needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
       
        # append city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_weather})

# if an error is experienced, skip city
    except:
        print("City not found. Skipping...")
        pass

# indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ancud
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | shirokiy
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | amot
# Processing Record 7 of Set 1 | gdynia
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | bathsheba
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | narsaq
# Processing Record 14 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 1 | bani
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | kavieng
# Processing Record 18 of Set 1 | vostok
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | kruisfontein
# Processing Record 24 of Set 1 | port blair
# Processing Record 25 of Set 1 | barstow
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | hualmay
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | santa maria
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | draguignan
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | port lincoln
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | shkotovo-26
# City not found. Skipping...
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | paso de ovejas
# Processing Record 45 of Set 1 | puerto baquerizo moreno
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | valer
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | dengzhou
# Processing Record 50 of Set 1 | kaitangata
# Processing Record 1 of Set 2 | gueret
# Processing Record 2 of Set 2 | te anau
# Processing Record 3 of Set 2 | gazli
# Processing Record 4 of Set 2 | hovd
# Processing Record 5 of Set 2 | oktyabrskoye
# Processing Record 6 of Set 2 | acapulco
# Processing Record 7 of Set 2 | veraval
# Processing Record 8 of Set 2 | husavik
# Processing Record 9 of Set 2 | ahipara
# Processing Record 10 of Set 2 | san cristobal
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | zhuhai
# Processing Record 13 of Set 2 | krasnoselkup
# Processing Record 14 of Set 2 | lethem
# Processing Record 15 of Set 2 | anamur
# Processing Record 16 of Set 2 | thunder bay
# Processing Record 17 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 2 | cabo san lucas
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | hun
# Processing Record 23 of Set 2 | ningxiang
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | saint-georges
# Processing Record 26 of Set 2 | chara
# Processing Record 27 of Set 2 | vestmanna
# Processing Record 28 of Set 2 | la romana
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | laguna
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | gutierrez
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 2 | sioux lookout
# Processing Record 36 of Set 2 | quatre cocos
# Processing Record 37 of Set 2 | makakilo city
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | frunze
# Processing Record 41 of Set 2 | la ronge
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 44 of Set 2 | homer
# Processing Record 45 of Set 2 | westport
# Processing Record 46 of Set 2 | rock sound
# Processing Record 47 of Set 2 | cranbrook
# Processing Record 48 of Set 2 | salym
# Processing Record 49 of Set 2 | ballina
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | banamba
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | haines junction
# Processing Record 7 of Set 3 | scottsbluff
# Processing Record 8 of Set 3 | poum
# Processing Record 9 of Set 3 | arlit
# Processing Record 10 of Set 3 | sile
# Processing Record 11 of Set 3 | mindelo
# Processing Record 12 of Set 3 | hami
# Processing Record 13 of Set 3 | gaillac
# Processing Record 14 of Set 3 | muravlenko
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | kolondieba
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | kargopol
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | port augusta
# Processing Record 21 of Set 3 | boddam
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | umba
# Processing Record 25 of Set 3 | manbij
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | faya
# Processing Record 28 of Set 3 | doha
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | quang ngai
# Processing Record 32 of Set 3 | grindavik
# Processing Record 33 of Set 3 | lavrentiya
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | tandalti
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | pula
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | mnogovershinnyy
# Processing Record 40 of Set 3 | namibe
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 3 | lasa
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | tarko-sale
# Processing Record 46 of Set 3 | bandundu
# Processing Record 47 of Set 3 | kasongo-lunda
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | primorsko-akhtarsk
# Processing Record 50 of Set 3 | naze
# Processing Record 1 of Set 4 | aykhal
# Processing Record 2 of Set 4 | sant cugat del valles
# Processing Record 3 of Set 4 | noshiro
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | svetlyy
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | encrucijada
# Processing Record 10 of Set 4 | dir
# Processing Record 11 of Set 4 | hilo
# Processing Record 12 of Set 4 | margate
# Processing Record 13 of Set 4 | kuhdasht
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | salalah
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | san francisco
# Processing Record 19 of Set 4 | meadow lake
# Processing Record 20 of Set 4 | simoes
# Processing Record 21 of Set 4 | at-bashi
# Processing Record 22 of Set 4 | kununurra
# Processing Record 23 of Set 4 | tual
# Processing Record 24 of Set 4 | narok
# Processing Record 25 of Set 4 | aginskoye
# Processing Record 26 of Set 4 | maua
# Processing Record 27 of Set 4 | gubkinskiy
# Processing Record 28 of Set 4 | russell
# Processing Record 29 of Set 4 | caruray
# Processing Record 30 of Set 4 | byron bay
# Processing Record 31 of Set 4 | bardiyah
# Processing Record 32 of Set 4 | roald
# Processing Record 33 of Set 4 | sembe
# Processing Record 34 of Set 4 | rio verde de mato grosso
# Processing Record 35 of Set 4 | nobres
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | nome
# Processing Record 38 of Set 4 | cape town
# Processing Record 39 of Set 4 | yekaterinoslavka
# Processing Record 40 of Set 4 | college
# Processing Record 41 of Set 4 | carutapera
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | tongliao
# Processing Record 44 of Set 4 | maralal
# Processing Record 45 of Set 4 | morondava
# Processing Record 46 of Set 4 | mananjary
# Processing Record 47 of Set 4 | tezu
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | tsabong
# Processing Record 50 of Set 4 | pinawa
# Processing Record 1 of Set 5 | una
# Processing Record 2 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 5 | los llanos de aridane
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | isangel
# Processing Record 9 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 5 | rundu
# Processing Record 11 of Set 5 | barrow
# Processing Record 12 of Set 5 | palora
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 5 | nouakchott
# Processing Record 16 of Set 5 | padang
# Processing Record 17 of Set 5 | pacocha
# Processing Record 18 of Set 5 | half moon bay
# Processing Record 19 of Set 5 | caucasia
# Processing Record 20 of Set 5 | moussoro
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | bandarbeyla
# Processing Record 23 of Set 5 | baghdad
# Processing Record 24 of Set 5 | staryy nadym
# Processing Record 25 of Set 5 | sovetskaya gavan
# Processing Record 26 of Set 5 | yaan
# Processing Record 27 of Set 5 | chilca
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 5 | banff
# Processing Record 31 of Set 5 | camacha
# Processing Record 32 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | gimli
# Processing Record 35 of Set 5 | tigil
# Processing Record 36 of Set 5 | raton
# Processing Record 37 of Set 5 | kiunga
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 5 | norman wells
# Processing Record 42 of Set 5 | conceicao do araguaia
# Processing Record 43 of Set 5 | rio cuarto
# Processing Record 44 of Set 5 | luanda
# Processing Record 45 of Set 5 | ilo
# Processing Record 46 of Set 5 | floro
# Processing Record 47 of Set 5 | rosetta
# Processing Record 48 of Set 5 | khirkiya
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 5 | ler
# Processing Record 1 of Set 6 | alekseyevsk
# Processing Record 2 of Set 6 | shingu
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | sorland
# Processing Record 5 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 6 | southbridge
# Processing Record 7 of Set 6 | banda aceh
# Processing Record 8 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 6 | isabela
# Processing Record 10 of Set 6 | hvolsvollur
# Processing Record 11 of Set 6 | surin
# Processing Record 12 of Set 6 | llangefni
# Processing Record 13 of Set 6 | torres
# Processing Record 14 of Set 6 | linjiang
# Processing Record 15 of Set 6 | huanren
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | neiafu
# Processing Record 18 of Set 6 | vero beach
# Processing Record 19 of Set 6 | xining
# Processing Record 20 of Set 6 | khandyga
# Processing Record 21 of Set 6 | bundaberg
# Processing Record 22 of Set 6 | chahuites
# Processing Record 23 of Set 6 | prince rupert
# Processing Record 24 of Set 6 | berdigestyakh
# Processing Record 25 of Set 6 | toro
# Processing Record 26 of Set 6 | kaeo
# Processing Record 27 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 6 | codrington
# Processing Record 29 of Set 6 | labuhan
# Processing Record 30 of Set 6 | barda
# Processing Record 31 of Set 6 | bethel
# Processing Record 32 of Set 6 | cidreira
# Processing Record 33 of Set 6 | mocuba
# Processing Record 34 of Set 6 | marienburg
# Processing Record 35 of Set 6 | constitucion
# Processing Record 36 of Set 6 | kalachinsk
# Processing Record 37 of Set 6 | road town
# Processing Record 38 of Set 6 | nipawin
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | serebryansk
# Processing Record 41 of Set 6 | ribeira grande
# Processing Record 42 of Set 6 | tsiroanomandidy
# Processing Record 43 of Set 6 | peniche
# Processing Record 44 of Set 6 | alta
# Processing Record 45 of Set 6 | kalmar
# Processing Record 46 of Set 6 | sabzevar
# Processing Record 47 of Set 6 | bosaso
# Processing Record 48 of Set 6 | bambous virieux
# Processing Record 49 of Set 6 | aviles
# Processing Record 50 of Set 6 | rio gallegos
# Processing Record 1 of Set 7 | manggar
# Processing Record 2 of Set 7 | mehran
# Processing Record 3 of Set 7 | mahebourg
# Processing Record 4 of Set 7 | bonavista
# Processing Record 5 of Set 7 | padilla
# Processing Record 6 of Set 7 | evensk
# Processing Record 7 of Set 7 | yangambi
# Processing Record 8 of Set 7 | torbay
# Processing Record 9 of Set 7 | samarai
# Processing Record 10 of Set 7 | ca mau
# Processing Record 11 of Set 7 | hasaki
# Processing Record 12 of Set 7 | ostrovnoy
# Processing Record 13 of Set 7 | lima
# Processing Record 14 of Set 7 | atherton
# Processing Record 15 of Set 7 | majene
# Processing Record 16 of Set 7 | golden
# Processing Record 17 of Set 7 | fairbanks
# Processing Record 18 of Set 7 | touros
# Processing Record 19 of Set 7 | hagenow
# Processing Record 20 of Set 7 | cambridge
# Processing Record 21 of Set 7 | airai
# Processing Record 22 of Set 7 | sechura
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | buchanan
# Processing Record 25 of Set 7 | pevek
# Processing Record 26 of Set 7 | harper
# Processing Record 27 of Set 7 | lata
# Processing Record 28 of Set 7 | catia la mar
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | kapuskasing
# Processing Record 31 of Set 7 | san juan
# Processing Record 32 of Set 7 | son la
# Processing Record 33 of Set 7 | mogadishu
# Processing Record 34 of Set 7 | vary
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 7 | kunda
# Processing Record 38 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 7 | anadyr
# Processing Record 40 of Set 7 | dingle
# Processing Record 41 of Set 7 | conde
# Processing Record 42 of Set 7 | severo-kurilsk
# Processing Record 43 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 44 of Set 7 | lagoa
# Processing Record 45 of Set 7 | huarmey
# Processing Record 46 of Set 7 | sao filipe
# Processing Record 47 of Set 7 | chadiza
# Processing Record 48 of Set 7 | dehloran
# Processing Record 49 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 7 | srandakan
# Processing Record 1 of Set 8 | honiara
# Processing Record 2 of Set 8 | caravelas
# Processing Record 3 of Set 8 | nicoya
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | itarema
# Processing Record 6 of Set 8 | jumla
# Processing Record 7 of Set 8 | lodwar
# Processing Record 8 of Set 8 | vokhma
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | atar
# Processing Record 11 of Set 8 | ayagoz
# Processing Record 12 of Set 8 | hirara
# Processing Record 13 of Set 8 | tomatlan
# Processing Record 14 of Set 8 | chunskiy
# Processing Record 15 of Set 8 | chapais
# Processing Record 16 of Set 8 | hammerfest
# Processing Record 17 of Set 8 | liku
# Processing Record 18 of Set 8 | cosala
# Processing Record 19 of Set 8 | svetlogorsk
# Processing Record 20 of Set 8 | ust-ishim
# Processing Record 21 of Set 8 | severodvinsk
# Processing Record 22 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 8 | karaton
# Processing Record 24 of Set 8 | homestead
# Processing Record 25 of Set 8 | havre
# Processing Record 26 of Set 8 | marzuq
# Processing Record 27 of Set 8 | maragogi
# Processing Record 28 of Set 8 | ndele
# Processing Record 29 of Set 8 | zhigansk
# Processing Record 30 of Set 8 | krasnaya poyma
# Processing Record 31 of Set 8 | mao
# Processing Record 32 of Set 8 | fortuna
# Processing Record 33 of Set 8 | merauke
# Processing Record 34 of Set 8 | srednekolymsk
# Processing Record 35 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 8 | coahuayana
# Processing Record 37 of Set 8 | gazanjyk
# Processing Record 38 of Set 8 | bajil
# Processing Record 39 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 40 of Set 8 | itoman
# Processing Record 41 of Set 8 | jhajjar
# Processing Record 42 of Set 8 | houma
# Processing Record 43 of Set 8 | yerbogachen
# Processing Record 44 of Set 8 | saint-augustin
# Processing Record 45 of Set 8 | vyartsilya
# Processing Record 46 of Set 8 | richards bay
# Processing Record 47 of Set 8 | kodiak
# Processing Record 48 of Set 8 | nyurba
# Processing Record 49 of Set 8 | dunedin
# Processing Record 50 of Set 8 | porto belo
# Processing Record 1 of Set 9 | duverge
# Processing Record 2 of Set 9 | zalantun
# Processing Record 3 of Set 9 | yarkovo
# Processing Record 4 of Set 9 | fort madison
# Processing Record 5 of Set 9 | daro
# Processing Record 6 of Set 9 | tautira
# Processing Record 7 of Set 9 | porto santo
# Processing Record 8 of Set 9 | solec kujawski
# Processing Record 9 of Set 9 | el tigre
# Processing Record 10 of Set 9 | tiznit
# Processing Record 11 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 9 | sistranda
# Processing Record 13 of Set 9 | flin flon
# Processing Record 14 of Set 9 | nova olinda do norte
# Processing Record 15 of Set 9 | bridgewater
# Processing Record 16 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | nioro
# Processing Record 18 of Set 9 | genhe
# Processing Record 19 of Set 9 | pangani
# Processing Record 20 of Set 9 | katherine
# Processing Record 21 of Set 9 | arman
# Processing Record 22 of Set 9 | gornopravdinsk
# Processing Record 23 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 9 | grand gaube
# Processing Record 25 of Set 9 | paamiut
# Processing Record 26 of Set 9 | akyab
# Processing Record 27 of Set 9 | camana
# Processing Record 28 of Set 9 | scarborough
# Processing Record 29 of Set 9 | guerrero negro
# Processing Record 30 of Set 9 | bilibino
# Processing Record 31 of Set 9 | dahod
# Processing Record 32 of Set 9 | tessalit
# Processing Record 33 of Set 9 | lensk
# Processing Record 34 of Set 9 | sahuaripa
# Processing Record 35 of Set 9 | cerro largo
# Processing Record 36 of Set 9 | turukhansk
# Processing Record 37 of Set 9 | esso
# Processing Record 38 of Set 9 | madison
# Processing Record 39 of Set 9 | moerai
# Processing Record 40 of Set 9 | ambatondrazaka
# Processing Record 41 of Set 9 | kundiawa
# Processing Record 42 of Set 9 | pochutla
# Processing Record 43 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 9 | pithoragarh
# Processing Record 45 of Set 9 | talnakh
# Processing Record 46 of Set 9 | tatawin
# Processing Record 47 of Set 9 | nathdwara
# Processing Record 48 of Set 9 | tura
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | bossangoa
# Processing Record 1 of Set 10 | paro
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | souillac
# Processing Record 4 of Set 10 | rocha
# Processing Record 5 of Set 10 | mbanza-ngungu
# Processing Record 6 of Set 10 | solnechnyy
# Processing Record 7 of Set 10 | rupert
# Processing Record 8 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 10 | vila franca do campo
# Processing Record 10 of Set 10 | pahrump
# Processing Record 11 of Set 10 | khani
# Processing Record 12 of Set 10 | tazovskiy
# Processing Record 13 of Set 10 | la union
# Processing Record 14 of Set 10 | sao joao do piaui
# Processing Record 15 of Set 10 | sitka
# Processing Record 16 of Set 10 | vardo
# Processing Record 17 of Set 10 | sarkand
# Processing Record 18 of Set 10 | mantua
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | jardim
# Processing Record 21 of Set 10 | maltahohe
# Processing Record 22 of Set 10 | tiksi
# Processing Record 23 of Set 10 | puerto escondido
# Processing Record 24 of Set 10 | necochea
# Processing Record 25 of Set 10 | fort walton beach
# Processing Record 26 of Set 10 | acarau
# Processing Record 27 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 28 of Set 10 | ampanihy
# Processing Record 29 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 10 | williamsport
# Processing Record 31 of Set 10 | parana
# Processing Record 32 of Set 10 | beringovskiy
# Processing Record 33 of Set 10 | ilam
# Processing Record 34 of Set 10 | manavalakurichi
# Processing Record 35 of Set 10 | manaure
# Processing Record 36 of Set 10 | iberia
# Processing Record 37 of Set 10 | kopervik
# Processing Record 38 of Set 10 | agadez
# Processing Record 39 of Set 10 | aripuana
# Processing Record 40 of Set 10 | kedougou
# Processing Record 41 of Set 10 | eureka
# Processing Record 42 of Set 10 | karratha
# Processing Record 43 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 10 | cabedelo
# Processing Record 45 of Set 10 | parabel
# Processing Record 46 of Set 10 | rio grande
# Processing Record 47 of Set 10 | kuah
# Processing Record 48 of Set 10 | mana
# Processing Record 49 of Set 10 | baglung
# Processing Record 50 of Set 10 | suruc
# Processing Record 1 of Set 11 | portobelo
# Processing Record 2 of Set 11 | praia da vitoria
# Processing Record 3 of Set 11 | rossland
# Processing Record 4 of Set 11 | monzon
# Processing Record 5 of Set 11 | kassala
# Processing Record 6 of Set 11 | klyuchi
# Processing Record 7 of Set 11 | vila do maio
# Processing Record 8 of Set 11 | buraydah
# Processing Record 9 of Set 11 | kresek
# Processing Record 10 of Set 11 | mananara
# Processing Record 11 of Set 11 | udankudi
# Processing Record 12 of Set 11 | shimoda
# Processing Record 13 of Set 11 | khadyzhensk
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | severnyy
# Processing Record 16 of Set 11 | port antonio
# Processing Record 17 of Set 11 | mercedes
# Processing Record 18 of Set 11 | natal
# Processing Record 19 of Set 11 | magadan
# Processing Record 20 of Set 11 | muros
# Processing Record 21 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 11 | parfino
# Processing Record 23 of Set 11 | vestmannaeyjar
# Processing Record 24 of Set 11 | ucluelet
# Processing Record 25 of Set 11 | talara
# Processing Record 26 of Set 11 | partenit
# Processing Record 27 of Set 11 | cuiaba
# Processing Record 28 of Set 11 | kawalu
# Processing Record 29 of Set 11 | ingleside
# Processing Record 30 of Set 11 | chumikan
# Processing Record 31 of Set 11 | jensen beach
# Processing Record 32 of Set 11 | pudozh
# Processing Record 33 of Set 11 | hauterive
# Processing Record 34 of Set 11 | xai-xai
# Processing Record 35 of Set 11 | champerico
# Processing Record 36 of Set 11 | asyut
# Processing Record 37 of Set 11 | olavarria
# Processing Record 38 of Set 11 | mount gambier
# Processing Record 39 of Set 11 | londiani
# Processing Record 40 of Set 11 | west bay
# Processing Record 41 of Set 11 | alofi
# Processing Record 42 of Set 11 | kahului
# Processing Record 43 of Set 11 | carberry
# Processing Record 44 of Set 11 | bassila
# Processing Record 45 of Set 11 | silifke
# Processing Record 46 of Set 11 | were ilu
# Processing Record 47 of Set 11 | basco
# Processing Record 48 of Set 11 | ngama
# Processing Record 49 of Set 11 | kralendijk
# Processing Record 50 of Set 11 | flinders
# Processing Record 1 of Set 12 | pelym
# Processing Record 2 of Set 12 | gigmoto
# Processing Record 3 of Set 12 | san miguel
# Processing Record 4 of Set 12 | san borja
# Processing Record 5 of Set 12 | sumbe
# Processing Record 6 of Set 12 | redlands
# Processing Record 7 of Set 12 | lady frere
# Processing Record 8 of Set 12 | vao
# Processing Record 9 of Set 12 | sant julia de loria
# Processing Record 10 of Set 12 | ornskoldsvik
# Processing Record 11 of Set 12 | pocinhos
# Processing Record 12 of Set 12 | poronaysk
# Processing Record 13 of Set 12 | grootfontein
# Processing Record 14 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 12 | krasnoarmeysk
# Processing Record 16 of Set 12 | komsomolskiy
# Processing Record 17 of Set 12 | vilyuysk
# Processing Record 18 of Set 12 | warman
# Processing Record 19 of Set 12 | shipitsyno
# Processing Record 20 of Set 12 | mitsamiouli
# Processing Record 21 of Set 12 | tavai
# City not found. Skipping...
# Processing Record 22 of Set 12 | abu dhabi
# Processing Record 23 of Set 12 | kosh-agach
# Processing Record 24 of Set 12 | strezhevoy
# Processing Record 25 of Set 12 | halifax
# Processing Record 26 of Set 12 | egvekinot
# Processing Record 27 of Set 12 | elwood
# Processing Record 28 of Set 12 | vung tau
# Processing Record 29 of Set 12 | presidencia roque saenz pena
# Processing Record 30 of Set 12 | santa rosalia
# Processing Record 31 of Set 12 | eirunepe
# Processing Record 32 of Set 12 | dakar
# Processing Record 33 of Set 12 | mama
# Processing Record 34 of Set 12 | panalingaan
# Processing Record 35 of Set 12 | liverpool
# Processing Record 36 of Set 12 | nelson bay
# Processing Record 37 of Set 12 | novichikha
# Processing Record 38 of Set 12 | katsuura
# Processing Record 39 of Set 12 | vila velha
# Processing Record 40 of Set 12 | lekoni
# Processing Record 41 of Set 12 | qinhuangdao
# Processing Record 42 of Set 12 | amga
# Processing Record 43 of Set 12 | puerto del rosario
# Processing Record 44 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 12 | christchurch
# Processing Record 46 of Set 12 | oistins
# Processing Record 47 of Set 12 | dutlwe
# Processing Record 48 of Set 12 | norrtalje
# Processing Record 49 of Set 12 | central point
# Processing Record 50 of Set 12 | pozoblanco
# Processing Record 1 of Set 13 | nova russas
# Processing Record 2 of Set 13 | kasangulu
# Processing Record 3 of Set 13 | willowmore
# Processing Record 4 of Set 13 | south valley
# Processing Record 5 of Set 13 | garissa
# Processing Record 6 of Set 13 | riosucio
# Processing Record 7 of Set 13 | alice springs
# Processing Record 8 of Set 13 | modra
# Processing Record 9 of Set 13 | hambantota
# Processing Record 10 of Set 13 | oia
# Processing Record 11 of Set 13 | wagar
# Processing Record 12 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 13 of Set 13 | chicama
# Processing Record 14 of Set 13 | valle del guamuez
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | kannur
# Processing Record 17 of Set 13 | vanavara
# Processing Record 18 of Set 13 | ambunti
# Processing Record 19 of Set 13 | port macquarie
# Processing Record 20 of Set 13 | medeiros neto
# Processing Record 21 of Set 13 | craidorolt
# Processing Record 22 of Set 13 | tungor
# Processing Record 23 of Set 13 | khorixas
# Processing Record 24 of Set 13 | wawa
# Processing Record 25 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 13 | tagusao
# Processing Record 27 of Set 13 | aquiraz
# Processing Record 28 of Set 13 | lexington
# Processing Record 29 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 13 | pangkalanbuun
# Processing Record 31 of Set 13 | surt
# Processing Record 32 of Set 13 | ixtapa
# Processing Record 33 of Set 13 | meulaboh
# Processing Record 34 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 13 | cervo
# Processing Record 36 of Set 13 | mehamn
# Processing Record 37 of Set 13 | korla
# Processing Record 38 of Set 13 | nixa
# Processing Record 39 of Set 13 | melfort
# Processing Record 40 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 41 of Set 13 | fort nelson
# Processing Record 42 of Set 13 | santa rosa
# Processing Record 43 of Set 13 | dondo
# Processing Record 44 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 13 | minbu
# Processing Record 46 of Set 13 | bonthe
# Processing Record 47 of Set 13 | avera
# Processing Record 48 of Set 13 | taoudenni
# Processing Record 49 of Set 13 | sevsk
# Processing Record 50 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 14 | senanga
# Processing Record 2 of Set 14 | opportunity
# Processing Record 3 of Set 14 | vaitape
# Processing Record 4 of Set 14 | tiarei
# Processing Record 5 of Set 14 | mahibadhoo
# Processing Record 6 of Set 14 | trinidad
# Processing Record 7 of Set 14 | osa
# Processing Record 8 of Set 14 | charters towers
# Processing Record 9 of Set 14 | namatanai
# Processing Record 10 of Set 14 | saint-joseph
# Processing Record 11 of Set 14 | viedma
# Processing Record 12 of Set 14 | maniitsoq
# Processing Record 13 of Set 14 | skjervoy
# Processing Record 14 of Set 14 | anqing
# Processing Record 15 of Set 14 | safakulevo
# Processing Record 16 of Set 14 | paracatu
# Processing Record 17 of Set 14 | fare
# Processing Record 18 of Set 14 | atambua
# Processing Record 19 of Set 14 | goderich
# Processing Record 20 of Set 14 | inuvik
# Processing Record 21 of Set 14 | a
# City not found. Skipping...
# Processing Record 22 of Set 14 | urumqi
# Processing Record 23 of Set 14 | chingirlau
# Processing Record 24 of Set 14 | eyl
# Processing Record 25 of Set 14 | eydhafushi
# Processing Record 26 of Set 14 | yuci
# Processing Record 27 of Set 14 | mogzon
# Processing Record 28 of Set 14 | inta
# Processing Record 29 of Set 14 | jackson
# Processing Record 30 of Set 14 | sungaipenuh
# Processing Record 31 of Set 14 | temnikov
# Processing Record 32 of Set 14 | salinopolis
# Processing Record 33 of Set 14 | millerovo
# Processing Record 34 of Set 14 | vanimo
# Processing Record 35 of Set 14 | novo aripuana
# Processing Record 36 of Set 14 | lae
# Processing Record 37 of Set 14 | kirakira
# Processing Record 38 of Set 14 | north bend
# Processing Record 39 of Set 14 | puerto colombia
# Processing Record 40 of Set 14 | okakarara
# Processing Record 41 of Set 14 | petatlan
# Processing Record 42 of Set 14 | aranos
# Processing Record 43 of Set 14 | banjar
# Processing Record 44 of Set 14 | beni mazar
# Processing Record 45 of Set 14 | honningsvag
# Processing Record 46 of Set 14 | ilyich
# Processing Record 47 of Set 14 | scalloway
# City not found. Skipping...
# Processing Record 48 of Set 14 | ormond beach
# Processing Record 49 of Set 14 | teguise
# Processing Record 50 of Set 14 | salina
# Processing Record 1 of Set 15 | vermilion
# Processing Record 2 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 15 | kargil
# Processing Record 4 of Set 15 | osoyoos
# Processing Record 5 of Set 15 | aitape
# Processing Record 6 of Set 15 | ye
# City not found. Skipping...
# Processing Record 7 of Set 15 | coihaique
# Processing Record 8 of Set 15 | griffith
# Processing Record 9 of Set 15 | manacapuru
# Processing Record 10 of Set 15 | daloa
# Processing Record 11 of Set 15 | oum hadjer
# Processing Record 12 of Set 15 | brownsville
# Processing Record 13 of Set 15 | luderitz
# Processing Record 14 of Set 15 | handwara
# City not found. Skipping...
# Processing Record 15 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 15 | saint-pierre
# Processing Record 17 of Set 15 | northam
# Processing Record 18 of Set 15 | gazalkent
# Processing Record 19 of Set 15 | gratia
# Processing Record 20 of Set 15 | havoysund
# Processing Record 21 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 15 | makat
# Processing Record 23 of Set 15 | praia
# Processing Record 24 of Set 15 | hailun
# Processing Record 25 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 15 | knysna
# Processing Record 27 of Set 15 | novikovo
# Processing Record 28 of Set 15 | falmouth
# Processing Record 29 of Set 15 | strenci
# Processing Record 30 of Set 15 | nizwa
# Processing Record 31 of Set 15 | moerdijk
# Processing Record 32 of Set 15 | houston
# Processing Record 33 of Set 15 | chanal
# Processing Record 34 of Set 15 | battle creek
# Processing Record 35 of Set 15 | lumsden
# Processing Record 36 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 37 of Set 15 | tianpeng
# Processing Record 38 of Set 15 | goiatuba
# Processing Record 39 of Set 15 | tilichiki
# Processing Record 40 of Set 15 | kolpashevo
# Processing Record 41 of Set 15 | afua
# Processing Record 42 of Set 15 | masakin
# Processing Record 43 of Set 15 | mount isa
# Processing Record 44 of Set 15 | mayumba
# Processing Record 45 of Set 15 | oussouye
# Processing Record 46 of Set 15 | betare oya
# Processing Record 47 of Set 15 | bulungu
# Processing Record 48 of Set 15 | rafaela
# Processing Record 49 of Set 15 | balikpapan
# Processing Record 50 of Set 15 | pirsagi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of dictionaries to a dataframe and order columns
city_data_df = pd.DataFrame(city_data, columns=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"])
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ancud      CL -41.8697  -73.8203     42.22        72         100
# 1      Albany      US  42.6001  -73.9662     79.21        73          96
# 2    Shirokiy      RU  49.7580  129.5230     73.15        84          95
# 3   Ilulissat      GL  69.2167  -51.1000     44.62        81          40
# 4  Nikolskoye      RU  59.7035   30.7861     66.09        64          26
# 5        Amot      NO  59.5714    7.9877     51.51        93         100
# 6      Gdynia      PL  54.5189   18.5319     67.12        88           0
# 7      Atuona      PF  -9.8000 -139.0333     77.50        76           2
# 8    Saldanha      ZA -33.0117   17.9442     59.05        92           1
# 9   Bathsheba      BB  13.2167  -59.5167     83.01        93          40
#
#    Wind Speed Current Description
# 0       12.84     overcast clouds
# 1        5.75       moderate rain
# 2        6.80     overcast clouds
# 3        9.22    scattered clouds
# 4        4.54    scattered clouds
# 5        3.04     overcast clouds
# 6        6.91           clear sky
# 7        8.72           clear sky
# 8       17.07           clear sky
# 9       19.57    scattered clouds

# %%
# create the output file (csv)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# export the City_Data into csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
